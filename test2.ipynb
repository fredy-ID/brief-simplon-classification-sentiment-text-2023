# %%
import requests
import functions as fn
from urllib.parse import urlparse
from bs4 import BeautifulSoup

URL = "https://community.o2.co.uk/t5/Discussions-Feedback/bd-p/4"
domain = urlparse(URL).netloc
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

last_page_link_number = fn.getLastPageUrl(soup)

def getThreads(results, threads):
    # get all threads titles and urls
    for thread_title in results:
        first_element = thread_title.find("div") # get first children - the div
        link = first_element.find("a")
        
        title = link["title"] # get the title and save it 
        url = link["href"] # get the link towards the post of the thread 
        threads.append((title, url)) 
        
    return threads
        
        # TODO navigate through all the pages showing threads

def getPost(threads):

    # get all post content for each thread
    all_thread_posts = []
    for thread in threads:
        thread_posts = []
        thread_url_path = thread[1]
        soupObject = fn.getSoupObject(domain, thread_url_path)

        # thread_posts = fn.getPostsFromPage(soupObject, thread_posts)
        # next_page_url = fn.getNextPageUrl(soupObject)
        # # while next_page_url:
        # if next_page_url != None:  
        # # while counter <= 3:
        #     # get all posts for given a page
        #     #print(next_page_url)
        #     next_page_url_path = urlparse(next_page_url).path
        #     print(next_page_url_path)
        #     soupObject = fn.getSoupObject(domain, next_page_url_path)
        #     thread_posts = fn.getPostsFromPage(soupObject, thread_posts)
        #     next_page_url = fn.getNextPageUrl(soupObject)
        #     print("HERE WE GO AGAIN")
            
        print(f'Number of post extracted for the thread "{thread[0]}": {len(thread_posts)}')
        all_thread_posts.append((thread[0], thread_posts)) # adding tuples with the title of a thread and the array containing all the posts content of a thread
        print("Number of threads scrapped:", len(all_thread_posts))
    
print("the scrapping task is finished")
# TODO store data into a CSV or relational database

page_request_number = last_page_link_number - 2


while(last_page_link_number > page_request_number):
    threads = []
    
    # get all articles
    results = soup.find_all("article", class_="custom-message-tile")
    all_threads = getThreads(results, threads)
    getPost(all_threads)
    print(soup)
    next_page_url = fn.getNextPageUrl(soup)
    print(next_page_url)
    soup = fn.getSoupObject(domain, next_page_url)
    print(soup)
    page_request_number += 1
    # https://community.o2.co.uk/t5/Discussions-Feedback/bd-p/4/page/2
    # /t5/Discussions-Feedback/Community-platform-bugs-issues-and-suggestions/td-p/1550804/jump-to/first-unread-message
# Out:
# the scrapping task is finished
# OKOKOKOKOK ----- 33333
# OKOKOKOKOK ----- 4444
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/Community-platform-bugs-issues-and-suggestions/td-p/1550804/jump-to/first-unread-message
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/Guide-Updates/td-p/1363682/jump-to/first-unread-message
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/O2-Customer-Service-Live-Chat-positive-feedback-archive/td-p/1125286/jump-to/first-unread-message
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/O2-Data-Network-Unavailable-For-Hours-At-A-Time-At-Many-Popular/td-p/1568919/jump-to/first-unread-message
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/Sim-Lock-code/td-p/1571590/jump-to/first-unread-message
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/IMEI-barred-when-phone-lost-Now-its-been-found-O2-cannot/td-p/1523430/jump-to/first-unread-message
# OKOKOKOKOK ----- 9999  /t5/Discussions-Feedback/Board/td-p/1571365/jump-to/first-unread-message
# ...
